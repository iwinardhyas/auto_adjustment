# %%
import cv2
import numpy as np
import os

# %%
path = '/home/erwin/Desktop/test_ibuk2/'
for image in os.listdir(path):
    image_file = path + image
    img = cv2.imread(image_file)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    mean = cv2.mean(hsv)
    v_value = mean[2]
    print(image,'--------->',v_value)
# Out:
# 1_670074_DST0163_08:59:27.1769930.jpg ---------> 179.9266796875
# 1_670074_DST0163_08:59:27.17699590.jpg ---------> 221.3646484375
# 1_670074_DST0163_08:59:27.17699530.jpg ---------> 197.18101562500001
# 1_670074_DST0163_08:59:27.17699100.jpg ---------> 173.9576953125
# 1_670074_DST0163_08:59:27.176995.jpg ---------> 180.06968750000001
# 1_670074_DST0163_08:59:27.17699540.jpg ---------> 201.6994140625
# 1_670074_DST0163_08:59:27.1769980.jpg ---------> 175.6381640625
# 1_670074_DST0163_08:59:27.1769910.jpg ---------> 180.44539062500002
# 1_670074_DST0163_08:59:27.17699520.jpg ---------> 192.2051171875
# 1_670074_DST0163_08:59:27.17699550.jpg ---------> 205.9689453125
# 1_670074_DST0163_08:59:27.1769990.jpg ---------> 174.79375000000002
# 1_670074_DST0163_08:59:27.176995100.jpg ---------> 224.9468359375
# 1_670074_DST0163_08:59:27.17699580.jpg ---------> 217.71101562500002
# 1_670074_DST0163_08:59:27.17699560.jpg ---------> 210.037421875
# ...

# %%
def normalization(x):
    new_x = (x-0/(255-100))
    return new_x

# %%
image_file = '/home/erwin/Desktop/test_ibuk2/1_670074_DST0163_08:59:27.176995100.jpg'
# image_file = '/home/erwin/Desktop/photo_register/sasazdd.adalah99_sasazdd.adalah_945431.jpg'
img = cv2.imread(image_file)
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
mean = cv2.mean(hsv)
v_value = mean[2]

v = (v_value-0/(255-0))/255*10
print('--------->',v)
# Out:
# ---------> 8.821444546568628

# %%
cv2.imshow("Images", np.hstack([img, hsv]))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def adjust_gamma(image, gamma):
	# build a lookup table mapping the pixel values [0, 255] to
	# their adjusted gamma values
	invGamma = 1.0 / gamma
	table = np.array([((i / 255.0) ** invGamma) * 255
		for i in np.arange(0, 256)]).astype("uint8")
 
	# apply gamma correction using the lookup table
	return cv2.LUT(image, table)

# %%
# original = cv2.imread('/home/erwin/Desktop/test_ibuk2/1_670074_DST0163_08:59:27.1769930.jpg')
original = cv2.imread('/home/erwin/Desktop/photo_register/sasazdd.adalah99_sasazdd.adalah_945431.jpg')
for gamma in np.arange(0.0, 5.5, 0.5):
	# ignore when gamma is 1 (there will be no change to the image)
	if gamma == 1:
		continue
 
	# apply gamma correction and show the images
	gamma = gamma if gamma > 0 else 0.1
	adjusted = adjust_gamma(original, gamma=gamma)
	cv2.putText(adjusted, "g={}".format(gamma), (10, 30),
		cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 3)
	cv2.imshow("Images", np.hstack([original, adjusted]))
	cv2.waitKey(0)
#     cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3e77d21c1fa0> in <module>
#       8         # apply gamma correction and show the images
#       9         gamma = gamma if gamma > 0 else 0.1
# ---> 10         adjusted = adjust_gamma(original, gamma=gamma)
#      11 	cv2.putText(adjusted, "g={}".format(gamma), (10, 30),
#      12 		cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 3)
#
# NameError: name 'adjust_gamma' is not defined

# %%
path = '/home/erwin/Desktop/test_ibuk2/'
gamma = 10
v_value_std = 1.5
for image in os.listdir(path):
    image_file = path + image
    img = cv2.imread(image_file)
    if v_value < 255:
        for i in np.arange(10,0,-0.1):
            adjusted = adjust_gamma(img, i)
            hsv = cv2.cvtColor(adjusted, cv2.COLOR_BGR2HSV)
            mean = cv2.mean(hsv)
            v_value = mean[2]
            
            cv2.putText(adjusted, "g={}".format(gamma), (10, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 3)
            cv2.imshow("Images", np.hstack([img, adjusted]))
            cv2.waitKey(0)
            cv2.destroyAllWindows()

# %%
# %%timeit
path = '/home/erwin/Desktop/photo_register/sasazdd.adalah99_sasazdd.adalah_945431.jpg'
# path = '/home/erwin/Desktop/tes_train/785593/1_785593_DST0283_13:50:24.398901.jpg'
# path = '/home/erwin/Desktop/test_ibuk2/1_670074_DST0163_08:59:27.176995100.jpg'
# path = '/home/erwin/Desktop/tes_train/815719/1_815719_DST0104_15:21:23.082947.jpg'
# path = '/home/erwin/Desktop/tes_train/815757/9_815757_DST0138_08:10:24.319291.jpg'
# path = '/home/erwin/Desktop/tes_train/7431897/1_7431897_DST0115_16:41:58.906326.jpg'
# path = '/home/erwin/Desktop/test_ibuk2/1_670074_DST0163_08:59:27.176995100.jpg'
img = cv2.imread(path)

def autotes (img):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    mean = cv2.mean(hsv)
    v_value = mean[2]
#     print('----->', v_value)
    # if v_value < 255:
    for i in np.arange(3,1.5,-0.1):
        gamma = i
        adjusted = adjust_gamma(img, gamma)
        hsv = cv2.cvtColor(adjusted, cv2.COLOR_BGR2HSV)
        mean = cv2.mean(hsv)
        v_value = mean[2]
#         print(v_value,'.....'+str(gamma))
        if v_value >= 121.0 and v_value <= 126.0:
            break
            
    return adjusted
adjusted = autotes(img)
cv2.putText(adjusted, "g={}".format(gamma), (10, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 3)
cv2.imshow("Images", np.hstack([img, adjusted]))
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# -----> 43.32328125
# -----> 43.32328125
# -----> 43.32328125
# -----> 43.32328125
# -----> 43.32328125
# -----> 43.32328125
# -----> 43.32328125
# -----> 43.32328125
# 243 ms ± 28.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
v = 125
V_new = ((10-0)/(255-0))*(v-0)+0
print(V_new)
# Out:
# 4.901960784313726

# %%
import cv2
import numpy as np
from PIL import Image
path = '/home/erwin/Desktop/tes_train/7431897/1_7431897_DST0115_16:41:58.906326.jpg'
# path = '/home/erwin/Desktop/test_ibuk2/1_670074_DST0163_08:59:27.176995100.jpg'
img = cv2.imread(path)
adjusted = adjust_gamma(img, 1.5)
# hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
# hue, sat, val = hsv[:,:,0], hsv[:,:,1], hsv[:,:,2]
# hsv[:,:,2]=100
# image = cv2.merge([hue,sat,val])
# img = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
cv2.imshow('tes',adjusted)
cv2.waitKey(0)
cv2.destroyAllWindows()
# print(val)
# b = np.mean(hsv[:,:,2])
# print(b)

# %%
import cv2
import os
import pandas as np
import statistics

path_1 = "/home/erwin/Desktop/tes_train/"
for folder in os.listdir(path_1):
    array = []
    path_2 = path_1+folder
    folder_new = ''
    for folder_1 in os.listdir(path_2):
        file = path_2+"/"+folder_1
        img = cv2.imread(file)
        hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
        mean = cv2.mean(hsv)
        v_value = mean[2]
        array.append(v_value)
        folder_1 = folder_new
        print(v_value)
#         if folder_1 == folder_new:
#             print("lalalala")
# Out:
# 210.8012109375
# 210.2754296875
# 208.4171875
# 210.26921875
# 213.407890625
# 221.1763671875
# 209.53273437500002
# 210.2641015625
# 210.30742187500002
# 209.9669921875
# 208.0666015625
# 212.81390625
# 211.88734375
# 211.40515625
# 210.784140625
# 210.4631640625
# 209.9581640625
# 210.0982421875
# 211.0683984375
# 212.1022265625
# 210.3785546875
# 210.44343750000002
# 211.041484375
# 212.67984375
# 211.9927734375
# 212.94273437500001
# 210.2841796875
# 212.40757812500001
# 209.749921875
# 212.6953515625
# 211.6046484375
# 211.6334765625
# 210.8342578125
# 211.4509375
# 210.815625
# 210.05328125
# 210.85136718750002
# 211.62773437500002
# 212.6673828125
# 211.07640625
# 212.4605078125
# 211.4005078125
# 220.3159765625
# 208.1184375
# 210.1648828125
# 213.026328125
# 209.2356640625
# 210.1305078125
# 210.900546875
# 211.82500000000002
# 210.1073046875
# 215.2298828125
# 211.4782421875
# 210.98375000000001
# 212.643125
# 220.615390625
# 211.95054687500001
# 212.3539453125
# ...

# %%
def manually_brightness(frame,brightness=27,contrast=10):
    frame = np.int16(frame)
    frame = frame * (contrast/127+1) - contrast + brightness
    frame = np.clip(frame, 0, 255)
    frame = np.uint8(frame)

    return frame

# %%
import cv2
import numpy as np


img = cv2.imread(path)
img2 = manually_brightness(img)
gambar = np.concatenate((img,img2), axis=1)
cv2.imshow('tes',gambar)
cv2.waitKey(0)
cv2.destroyAllWindows()
